# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_excel(r'/Users/rinki/Desktop/Avacado Project.xlsx')
data
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0               0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4 2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...        ...           ...           ...      ...        ...
# 18244           7 2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8 2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9 2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  datetime64[ns]
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(2), object(2)
# memory usage: 1.9+ MB

# %%
data.dtypes
# Out:
# Unnamed: 0               int64
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# dtype: object

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
data.isna().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
data.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
data.columns
# Out:
# Index([        'Date', 'AveragePrice', 'Total Volume',           4046,
#                  4225,           4770,   'Total Bags',   'Small Bags',
#          'Large Bags',  'XLarge Bags',         'type',         'year',
#              'region'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.scatter(x='AveragePrice',y='Date',data=data,s=50,c='g')

# %%
plt.scatter(x='Total Volume',y='AveragePrice',data=data,c='y')

# %%
plt.scatter(x='Total Bags',y='AveragePrice',data=data,c='y')

# %%
plt.hist(data[4046],color='red',bins=30)
plt.show()

# %%
plt.hist(data[4225],color='green',bins=30)
plt.show()

# %%
plt.hist(data[4770],color='black',bins=30)
plt.show()

# %%
#Categorical Data Visualization
data_visualization_nominal=data[['Date', 'AveragePrice', 'Total Volume',           4046,
                 4225,           4770,   'Total Bags',   'Small Bags',
         'Large Bags',  'XLarge Bags',         'type',         'year',
             'region']].copy()

# %%
data=sns.countplot(x='type',hue='AveragePrice',data=data_visualization_nominal)
print(data_visualization_nominal['type'].value_counts())
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
data=sns.countplot(x='type',data=data_visualization_nominal)
print(data_visualization_nominal['type'].value_counts())
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
data=sns.countplot(x='year',hue='AveragePrice',data=data_visualization_nominal)
print(data_visualization_nominal['year'].value_counts())
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %%
data=sns.countplot(x='year',data=data_visualization_nominal)
print(data_visualization_nominal['year'].value_counts())
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %%
data['AveragePrice'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.scatterplot(x="AveragePrice",y='year',data=data)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='year'>

# %%
sns.scatterplot(x="AveragePrice",y='Total Volume',data=data)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Total Volume'>

# %%
sns.scatterplot(x="region",y='AveragePrice',data=data)
# Out:
# <AxesSubplot:xlabel='region', ylabel='AveragePrice'>

# %%
sns.scatterplot(x="region",y='Total Volume',data=data)
# Out:
# <AxesSubplot:xlabel='region', ylabel='Total Volume'>

# %%
sns.scatterplot(x="region",y=4046,data=data)
# Out:
# <AxesSubplot:xlabel='region', ylabel='4046'>

# %%
sns.scatterplot(x="region",y=4225,data=data)
# Out:
# <AxesSubplot:xlabel='region', ylabel='4225'>

# %%
sns.scatterplot(x="region",y=4770,data=data)
# Out:
# <AxesSubplot:xlabel='region', ylabel='4770'>

# %%
data.columns
# Out:
# Index([        'Date', 'AveragePrice', 'Total Volume',           4046,
#                  4225,           4770,   'Total Bags',   'Small Bags',
#          'Large Bags',  'XLarge Bags',         'type',         'year',
#              'region'],
#       dtype='object')

# %%
data.drop(['Date'],axis=1,inplace=True)

# %%
sns.pairplot(data)

# %%
#encoding dataframe
from sklearn.preprocessing import OrdinalEncoder
data_2=OrdinalEncoder()
for i in data.columns:
    if data[i].dtypes=='object':
        data[i]=data_2.fit_transform(data[i].values.reshape(-1,1))
data
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region
# ...

# %%
data.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          type  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507      0.499918
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(data.describe(), annot=True, linewidth=.5,linecolor='yellow')
# Out:
# <AxesSubplot:>

# %%
data.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# type              0.615845     -0.232434 -0.225819 -0.232289 -0.210027
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# region           -0.011716      0.174176  0.192073  0.145726  0.095252
#
# ...

# %%
data.corr()['AveragePrice'].sort_values()
# Out:
# 4046           -0.208317
# Total Volume   -0.192752
# 4770           -0.179446
# Total Bags     -0.177088
# Small Bags     -0.174730
# Large Bags     -0.172940
# 4225           -0.172928
# XLarge Bags    -0.117592
# region         -0.011716
# year            0.093197
# type            0.615845
# AveragePrice    1.000000
# Name: AveragePrice, dtype: float64

# %%
data.corr()['region'].sort_values()
# Out:
# AveragePrice   -0.011716
# type           -0.000280
# year           -0.000055
# XLarge Bags     0.082281
# 4770            0.095252
# 4225            0.145726
# Small Bags      0.164702
# Total Volume    0.174176
# Total Bags      0.175256
# 4046            0.192073
# Large Bags      0.198768
# region          1.000000
# Name: region, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), annot=True, linewidth=1,linecolor='black')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(6,6))
data.corr()['AveragePrice'].sort_values(ascending=False).drop(['AveragePrice']).plot(kind='bar',color='yellow')
plt.xlabel('sales data',fontsize=14)
plt.ylabel('column with target names',fontsize=16)
plt.title('correlation',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(5,5))
data.corr()['region'].sort_values(ascending=False).drop(['region']).plot(kind='bar',color='blue')
plt.xlabel('sales data',fontsize=14)
plt.ylabel('column with target names',fontsize=16)
plt.title('correlation',fontsize=20)
plt.show()

# %%
data.shape
# Out:
# (18249, 12)

# %%
#to check outliers
import warnings
warnings.filterwarnings("ignore")
collist=data.columns.values
ncol=3
nrows=4
plt.figure(figsize=(nrows,3*nrows))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data[collist[i]])
    plt.tight_layout()

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(data))
threshold=3
np.where(z>3)
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428]),
#  array([2, 2, 8, ..., 0, 0, 0]))

# %%
np.abs(zscore(data))<0
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
data_1=data[(z<3).all(axis=1)]
data_1
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region
# ...

# %%
#to know the percentage loss
loss_data=((18249-17651)/18249)*100
loss_data
# Out:
# 3.276891884486821

# %%
#distribution plot to check skewness
collist=data.columns.values
ncol=2
nrows=6
plt.figure(figsize=(nrows,2*nrows))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(data[collist[i]])
    plt.tight_layout()

# %%
#check skewness in data
data.skew().sort_values()
# Out:
# region           0.000030
# type             0.000329
# year             0.215339
# AveragePrice     0.580303
# 4046             8.648220
# 4225             8.942466
# Total Volume     9.007687
# Small Bags       9.540660
# Total Bags       9.756072
# Large Bags       9.796455
# 4770            10.159396
# XLarge Bags     13.139751
# dtype: float64

# %%
x=data.drop('region',axis=1)
y=data['region']

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)
x=pd.DataFrame(x_new,columns=x.columns)
x.skew()
# Out:
# AveragePrice    0.006655
# Total Volume    0.035774
# 4046           -0.006438
# 4225            0.017923
# 4770            0.029971
# Total Bags      0.030980
# Small Bags      0.030153
# Large Bags      0.039828
# XLarge Bags     0.698965
# type            0.000329
# year            0.052750
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=670)
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
y_pred=rfr.predict(x_test)
rfr.score(x_train,y_train)
# Out:
# 0.9707977105944654

# %%
rfr.score(x_test,y_test)
# Out:
# 0.7901744126334493

# %%
sns.distplot(y_test-y_pred)
plt.show()

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
xgb_classifier=XGBClassifier()
xgb_classifier.fit(x_train,y_train)
y_pred_xgb=xgb_classifier.predict(x_test)
accuracy_score(y_test,y_pred_xgb)
# Out:
# 0.886259040105194

# %%
predictions=xgb_classifier.predict(x_test)
sns.distplot(y_test-predictions)
# Out:
# <AxesSubplot:xlabel='region', ylabel='Density'>

# %%
x_train_sc=sc.fit_transform(x_train)
x_test_sc=sc.transform(x_test)

# %%
#train with standard scaled data
xgb2=XGBClassifier()
xgb2.fit(x_train_sc,y_train)
y_pred_xgb_sc=xgb2.predict(x_test_sc)
accuracy_score(y_test,y_pred_xgb_sc)
# Out:
# 0.8864781941705019

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier=KNeighborsClassifier(n_neighbors=5, metric='minkowski',p=2)
knn_classifier.fit(x_train,y_train)
y_pred_knn=knn_classifier.predict(x_test)
accuracy_score(y_test,y_pred_knn)
# Out:
# 0.8562349331580101

# %%
predictions=knn_classifier.predict(x_test)
sns.distplot(y_test-predictions)
# Out:
# <AxesSubplot:xlabel='region', ylabel='Density'>

# %%
#train with standard scaled data
knn_classifier2=KNeighborsClassifier(n_neighbors=5, metric='minkowski',p=2)
knn_classifier2.fit(x_train_sc,y_train)
y_pred_knn_sc=knn_classifier.predict(x_test_sc)
accuracy_score(y_test,y_pred_knn_sc)
# Out:
# 0.8547008547008547

# %%
params={"learning_rate":[0.05,0.10,0.15,0.20,0.25,0.30],
       "max_depth":[3,4,5,6,8,10,12,15],
       "min_child_weight":[1,3,5,7],
       "gamma":[0.1,0.2,0.3,0.4],
       "colsample_bytree":[0.3,0.4,0.5,0.7]}
from sklearn.model_selection import RandomizedSearchCV
random_search=RandomizedSearchCV(xgb_classifier,param_distributions=params,scoring='roc_auc',n_iter=3,n_jobs=-1,verbose=3)
random_search.fit(x_train,y_train)
random_search.best_params_
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# {'min_child_weight': 3,
#  'max_depth': 12,
#  'learning_rate': 0.25,
#  'gamma': 0.4,
#  'colsample_bytree': 0.7}

# %%
random_search.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.7,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0.4, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.25, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=12, max_leaves=0, min_child_weight=3,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...)

# %%
#training XGBoost Classifier with best parameter
from numpy import nan
xgb=XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.7,
              early_stopping_rounds=None, enable_categorical=False,
              eval_metric=None, gamma=0.4, gpu_id=-1, grow_policy='depthwise',
              importance_type=None, interaction_constraints='',
              learning_rate=0.25, max_bin=256, max_cat_to_onehot=4,
              max_delta_step=0, max_depth=12, max_leaves=0, min_child_weight=3,
              missing=nan, monotone_constraints='()', n_estimators=100,
              n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
              predictor='auto', random_state=0, reg_alpha=0)
xgb.fit(x_train,y_train)
y_pred_xgb=xgb.predict(x_test)
accuracy_score(y_test,y_pred_xgb)
# Out:
# 0.8750821827744905

# %%
import joblib
joblib.dump(random_search.best_estimator_,"Avacado Project")
# Out:
# ['Avacado Project']
